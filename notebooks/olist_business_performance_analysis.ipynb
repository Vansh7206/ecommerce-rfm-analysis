# %% [markdown]
# # 🎯 Objective of This Project
# #### To analyze e-commerce sales performance, customer behavior, product performance, and seller effectiveness using SQL, Python, and Power BI.

# %% [markdown]
# ## Basic Info about Data
# # 1️⃣ customers
#
# Description:
# Contains information about customers who placed orders.
#
# Columns:
# 1. customer_id – Unique ID for each customer (Primary Key)
# 2. customer_unique_id – Unique identifier representing the real person
# 3. customer_city – Customer’s city
# 4. customer_state – Customer’s state
#
# Purpose in Project:
# Used for:
# - State-wise revenue analysis
# - Customer segmentation
# - Repeat customer analysis
#
# # 2️⃣ orders
#
# Description:
# Contains order-level information.
#
# Columns:
# 1. order_id – Unique order ID (Primary Key)
# 2. customer_id – Links to customers table (Foreign Key)
# 3. order_status – Status of order (delivered, canceled, etc.)
# 4. order_purchase_timestamp – Date and time of purchase
# 5. order_approved_at – When payment was approved
# 6. order_delivered_customer_date – Delivery date
# 7. order_estimated_delivery_date – Estimated delivery date
#
# Purpose in Project:
# Used for:
# - Monthly revenue trends
# - Delivery time analysis
# - Order status analysis
#
# # 3️⃣ order_items
#
# Description:
# Contains product-level details within each order.
#
# Columns:
# 1. order_id – Links to orders
# 2. order_item_id – Item number within order
# 3. product_id – Links to products
# 4. seller_id – Links to sellers
# 5. shipping_limit_date – Shipping deadline
# 6. price – Product price
# 7. freight_value – Shipping cost
#
# Purpose in Project:
# Used for:
# - Revenue calculation
# - Seller performance
# - Product performance
#
# # 4️⃣ products
#
# Description:
# Contains product-level details.
#
# Columns:
# 1. product_id – Unique product ID
# 2. product_category_name – Category name
# 3. product_name_lenght
# 4. product_description_lenght
# 5. product_photos_qty
# 6. product_weight_g
# 7. product_length_cm
# 8. product_height_cm
# 9. product_width_cm
#
# Purpose in Project:
# Used for:
# 1. Category performance analysis
# 2. Product-level analytics
#
# # 5️⃣ sellers
#
# Description:
# Contains seller information.
#
# Columns:
# 1. seller_id – Unique seller ID
# 2. seller_zip_code_prefix
# 3. seller_city
# 4. seller_state
#
# Purpose in Project:
# Used for:
# - Seller performance analysis
# - State-level sales analysis
#
# # 6️⃣ order_payments
#
# Description:
# Contains payment details for each order.
#
# Columns:
# 1. order_id – Links to orders
# 2. payment_sequential – Payment number
# 3. payment_type – Payment method (credit card, boleto, etc.)
# 4. payment_installments – Installment count
# 5. payment_value – Amount paid
#
# Purpose in Project:
# Used for:
# - Payment method analysis
# - Revenue validation
#
# # 7️⃣ category_translation
#
# Description:
# Translates Portuguese product categories into English.
#
# Columns:
# 1. product_category_name
# 2. product_category_name_english
#
# Purpose in Project:
# Used for:
# - Clean reporting
# - English category dashboards

# %% [markdown]
# ### SQL Connection

# %%
import pandas as pd
from sqlalchemy import create_engine

username = "postgres"
password = ""
host = "localhost"
port = "5432"
database = "ecommerce_analysis"

engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/{database}")

print("Connection Successful!")
# Out:
# Connection Successful!

# %% [markdown]
# ## PHASE 1 — Business Understanding + Initial Exploration

# %% [markdown]
# ### 1) Total Number of Customers

# %%
query = "SELECT COUNT(DISTINCT customer_unique_id) AS TOTAL_CUSTOMERS FROM CUSTOMERS;"
tc = pd.read_sql(query,engine)
tc
# Out:
#    total_customers
# 0            96096

# %% [markdown]
# ### 2) Total Number of Orders

# %%
query = "SELECT COUNT(*) AS TOTAL_ORDERS FROM ORDERS"
os = pd.read_sql(query,engine)
os
# Out:
#    total_orders
# 0         99441

# %% [markdown]
# ### 3) Total Number of Products

# %%
query = "SELECT COUNT(*) AS TOTAL_PRODUCTS FROM PRODUCTS;"
tp = pd.read_sql(query,engine)
tp
# Out:
#    total_products
# 0           32951

# %% [markdown]
# ### 4) Total Number of Products Categories

# %%
query = "SELECT COUNT(DISTINCT product_category_name) AS TOTAL_CATEGORIES FROM PRODUCTS;"
tp = pd.read_sql(query,engine)
tp
# Out:
#    total_categories
# 0                73

# %% [markdown]
# ### 5) Total Number of Sellers

# %%
query = "SELECT COUNT(DISTINCT seller_id) AS TOTAL_SELLERS FROM SELLERS;"
ts = pd.read_sql(query,engine)
ts
# Out:
#    total_sellers
# 0           3095

# %% [markdown]
# ## Revenue Calculation

# %% [markdown]
# ### 6) Total Revenue

# %%
query = "SELECT SUM(price+freight_value) AS TOTAL_REVENUE FROM ORDER_ITEMS;"
tr = pd.read_sql(query,engine)
tr
# Out:
#    total_revenue
# 0    15843553.24

# %% [markdown]
# ### 7) Average Order Value

# %%
query = "SELECT AVG(TOTAL_REVENUE) AS AVG_ORDER_VALUE FROM (SELECT ORDER_ID,SUM(price+freight_value) as TOTAL_REVENUE FROM ORDER_ITEMS GROUP BY ORDER_ID);"
avg_rev = pd.read_sql(query,engine)
avg_rev
# Out:
#    avg_order_value
# 0       160.577638

# %% [markdown]
# ### 8) Maximum Order Value

# %%
query = "SELECT MAX(TOTAL_REVENUE) AS MAX_ORDER_VALUE FROM (SELECT ORDER_ID,SUM(price+freight_value) AS TOTAL_REVENUE FROM ORDER_ITEMS GROUP BY ORDER_ID);"
max_rev = pd.read_sql(query, engine)
max_rev
# Out:
#    max_order_value
# 0         13664.08

# %% [markdown]
# ### 9) Minimum Order Value

# %%
query = "SELECT MIN(TOTAL_REVENUE) AS MIN_ORDER_VALUE FROM (SELECT ORDER_ID,SUM(price+freight_value) AS TOTAL_REVENUE FROM ORDER_ITEMS GROUP BY ORDER_ID);"
min_rev = pd.read_sql(query, engine)
min_rev
# Out:
#    min_order_value
# 0             9.59

# %% [markdown]
# ## ORDERS ANALYSIS

# %% [markdown]
# ### 10) Order Status Analysis

# %%
query = "SELECT ORDER_STATUS,COUNT(*) FROM ORDERS GROUP BY ORDER_STATUS ORDER BY COUNT DESC;"
order_status = pd.read_sql(query,engine)
order_status
# Out:
#   order_status  count
# 0    delivered  96478
# 1      shipped   1107
# 2     canceled    625
# 3  unavailable    609
# 4     invoiced    314
# 5   processing    301
# 6      created      5
# 7     approved      2

# %% [markdown]
# ### 11) Percentage of 'Delivered' Orders

# %%
query = "SELECT (COUNT(*) FILTER (WHERE ORDER_STATUS = 'delivered') * 100) / COUNT(*) AS DELIVER_SHARE_PERCENT FROM ORDERS;"
delivered = pd.read_sql(query,engine)
delivered
# Out:
#    deliver_share_percent
# 0                     97

# %% [markdown]
# ## Date Analysis

# %% [markdown]
# ### 12) First Date of Orders

# %%
query = "SELECT MIN(order_purchase_timestamp) AS FIRST_ORDER_DATE FROM ORDERS;"
min_date = pd.read_sql(query,engine)
min_date
# Out:
#      first_order_date
# 0 2016-09-04 21:15:19

# %% [markdown]
# ### 13) First Date of Orders

# %%
query = "SELECT MAX(order_purchase_timestamp) AS LAST_ORDER_DATE FROM ORDERS;"
min_date = pd.read_sql(query,engine)
min_date
# Out:
#       last_order_date
# 0 2018-10-17 17:30:18
